# %% [markdown]
# # Yelp Analysis
#
# For this notebook segment, I used the yelp API to determine where the 'hot and new' businesses are located. My rationale was that the areas where newer companies are located are most likely to be areas that are being gentrified. Unfortunately, there weren't that many results. Currently waiting on my Twitter API to see if I can access mobility patterns in different areas, which is a good indicator of gentrification:
#
# https://www.npr.org/sections/13.7/2017/08/29/546980178/what-does-it-take-to-see-gentrification-before-it-happens

# %%
import requests
import pandas as pd
from config import api_key

# %%
# Business Search URL
url = 'https://api.yelp.com/v3/businesses/search'

# %%
# Define the api key, define the endpoint and define the header
API_KEY = api_key
ENDPOINT = url
HEADERS = {'Authorization': 'bearer %s' % api_key}
# headers is how we authenticate ourselves

# %%
# Define the parameters
PARAMETERS = {'categories': 'coffee, restaurants, bars',
             'radius': 40000,
             'location': 'Austin',
             'attributes': 'hot_and_new'}

# %%
# Make a request to the yelp API
response = requests.get(url = ENDPOINT, params = PARAMETERS, headers = HEADERS)

# Convert JSON string to dictionary
biz_data = response.json()
print(biz_data)
# Out:
# {'businesses': [{'id': '82mMA_TH0GQM3WYgxKXREA', 'alias': 'zeds-real-fruit-ice-cream-austin', 'name': 'Zeds Real Fruit Ice Cream', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yhOH81g9UY_t36b20Eq0tg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/zeds-real-fruit-ice-cream-austin?adjust_creative=ZKVMq1fflAVchaGytTB-RQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZKVMq1fflAVchaGytTB-RQ', 'review_count': 13, 'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}, {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}], 'rating': 4.5, 'coordinates': {'latitude': 30.2821, 'longitude': -97.70573}, 'transactions': [], 'location': {'address1': '1814 Harvey St', 'address2': None, 'address3': '', 'city': 'Austin', 'zip_code': '78702', 'country': 'US', 'state': 'TX', 'display_address': ['1814 Harvey St', 'Austin, TX 78702']}, 'phone': '+15033955038', 'display_phone': '(503) 395-5038', 'distance': 5614.057430798926}, {'id': 't8MhdpBVeL2YxIUXx1kcfw', 'alias': 'ani-s-day-and-night-austin', 'name': 'Ani’s Day & Night', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/umrzV4DJR0vQDQdtM6ciig/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/ani-s-day-and-night-austin?adjust_creative=ZKVMq1fflAVchaGytTB-RQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZKVMq1fflAVchaGytTB-RQ', 'review_count': 10, 'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'bars', 'title': 'Bars'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}], 'rating': 4.5, 'coordinates': {'latitude': 30.22101, 'longitude': -97.6956}, 'transactions': [], 'location': {'address1': '7107 E Riverside Dr', 'address2': '', 'address3': None, 'city': 'Austin', 'zip_code': '78741', 'country': 'US', 'state': 'TX', 'display_address': ['7107 E Riverside Dr', 'Austin, TX 78741']}, 'phone': '+15127751355', 'display_phone': '(512) 775-1355', 'distance': 11097.854408045292}, {'id': 'eL_JhE6smEo128qAdiUr0Q', 'alias': '1417-austin', 'name': '1417', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cqESrFA03HvcG2fwgqukuQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/1417-austin?adjust_creative=ZKVMq1fflAVchaGytTB-RQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZKVMq1fflAVchaGytTB-RQ', 'review_count': 3, 'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}], 'rating': 4.5, 'coordinates': {'latitude': 30.25021368468073, 'longitude': -97.75457298368464}, 'transactions': [], 'location': {'address1': '1417 S 1st St', 'address2': '', 'address3': None, 'city': 'Austin', 'zip_code': '78704', 'country': 'US', 'state': 'TX', 'display_address': ['1417 S 1st St', 'Austin, TX 78704']}, 'phone': '', 'display_phone': '', 'distance': 6116.809130950481}, {'id': 'BRsU4qwL3hfdT6D5RbY2uA', 'alias': 'eat-my-biscuits-georgetown', 'name': 'Eat My Biscuits', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GaNRfgTF_vOWgXN9bwGvUA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/eat-my-biscuits-georgetown?adjust_creative=ZKVMq1fflAVchaGytTB-RQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZKVMq1fflAVchaGytTB-RQ', 'review_count': 20, 'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}], 'rating': 4.5, 'coordinates': {'latitude': 30.630148160480054, 'longitude': -97.74506705516937}, 'transactions': ['pickup', 'delivery'], 'location': {'address1': '3309 W State Hwy 29', 'address2': None, 'address3': '', 'city': 'Georgetown', 'zip_code': '78628', 'country': 'US', 'state': 'TX', 'display_address': ['3309 W State Hwy 29', 'Georgetown, TX 78628']}, 'phone': '+15125911129', 'display_phone': '(512) 591-1129', 'distance': 36157.74817256539}, {'id': 'nG ...

# %%
for biz in biz_data['businesses']:
    print(biz['location'])
# Out:
# {'address1': '1814 Harvey St', 'address2': None, 'address3': '', 'city': 'Austin', 'zip_code': '78702', 'country': 'US', 'state': 'TX', 'display_address': ['1814 Harvey St', 'Austin, TX 78702']}
# {'address1': '7107 E Riverside Dr', 'address2': '', 'address3': None, 'city': 'Austin', 'zip_code': '78741', 'country': 'US', 'state': 'TX', 'display_address': ['7107 E Riverside Dr', 'Austin, TX 78741']}
# {'address1': '1417 S 1st St', 'address2': '', 'address3': None, 'city': 'Austin', 'zip_code': '78704', 'country': 'US', 'state': 'TX', 'display_address': ['1417 S 1st St', 'Austin, TX 78704']}
# {'address1': '3309 W State Hwy 29', 'address2': None, 'address3': '', 'city': 'Georgetown', 'zip_code': '78628', 'country': 'US', 'state': 'TX', 'display_address': ['3309 W State Hwy 29', 'Georgetown, TX 78628']}
# {'address1': '1700 E Palm Valley Blvd', 'address2': None, 'address3': None, 'city': 'Round Rock', 'zip_code': '78664', 'country': 'US', 'state': 'TX', 'display_address': ['1700 E Palm Valley Blvd', 'Round Rock, TX 78664']}

# %%
df_nested_list = pd.json_normalize(biz_data)
df_nested_list
# Out:
#                                           businesses  total  \
# 0  [{'id': '82mMA_TH0GQM3WYgxKXREA', 'alias': 'ze...      5
#
#    region.center.longitude  region.center.latitude
# 0               -97.757721               30.305156

# %%
df_nested_list = pd.json_normalize(biz_data, record_path =['businesses'])
df_nested_list
# Out:
#                        id                             alias  \
# 0  82mMA_TH0GQM3WYgxKXREA  zeds-real-fruit-ice-cream-austin
# 1  t8MhdpBVeL2YxIUXx1kcfw        ani-s-day-and-night-austin
# 2  eL_JhE6smEo128qAdiUr0Q                       1417-austin
# 3  BRsU4qwL3hfdT6D5RbY2uA        eat-my-biscuits-georgetown
# 4  nGuzUPebA-jKvTMe6zrerA      dutch-bros-coffee-round-rock
#
#                         name  \
# 0  Zeds Real Fruit Ice Cream
# 1          Ani’s Day & Night
# 2                       1417
# 3            Eat My Biscuits
# 4          Dutch Bros Coffee
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/yhOH81...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/umrzV4...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/cqESrF...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/GaNRfg...      False
# 4  https://s3-media4.fl.yelpcdn.com/bphoto/PmOBW2...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/zeds-real-fruit-ice-c...            13
# 1  https://www.yelp.com/biz/ani-s-day-and-night-a...            10
# 2  https://www.yelp.com/biz/1417-austin?adjust_cr...             3
# 3  https://www.yelp.com/biz/eat-my-biscuits-georg...            20
# 4  https://www.yelp.com/biz/dutch-bros-coffee-rou...             8
#
#                                           categories  rating  \
# 0  [{'alias': 'icecream', 'title': 'Ice Cream & F...     4.5
# 1  [{'alias': 'foodtrucks', 'title': 'Food Trucks...     4.5
# 2  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...     4.5
# 3  [{'alias': 'foodtrucks', 'title': 'Food Trucks...     4.5
# 4  [{'alias': 'juicebars', 'title': 'Juice Bars &...     4.5
#
#          transactions  ... coordinates.latitude coordinates.longitude  \
# 0                  []  ...            30.282100            -97.705730
# 1                  []  ...            30.221010            -97.695600
# 2                  []  ...            30.250214            -97.754573
# 3  [pickup, delivery]  ...            30.630148            -97.745067
# 4                  []  ...            30.519441            -97.658651
#
#          location.address1  location.address2  location.address3  \
# 0           1814 Harvey St               None
# 1      7107 E Riverside Dr                                  None
# 2            1417 S 1st St                                  None
# 3      3309 W State Hwy 29               None
# 4  1700 E Palm Valley Blvd               None               None
#
#   location.city location.zip_code location.country location.state  \
# 0        Austin             78702               US             TX
# 1        Austin             78741               US             TX
# 2        Austin             78704               US             TX
# 3    Georgetown             78628               US             TX
# 4    Round Rock             78664               US             TX
#
#                           location.display_address
# 0               [1814 Harvey St, Austin, TX 78702]
# 1          [7107 E Riverside Dr, Austin, TX 78741]
# 2                [1417 S 1st St, Austin, TX 78704]
# 3      [3309 W State Hwy 29, Georgetown, TX 78628]
# 4  [1700 E Palm Valley Blvd, Round Rock, TX 78664]
#
# [5 rows x 23 columns]

# %%
df_nested_list = df_nested_list.drop(['id','alias','image_url',
                                      'display_phone','categories', 
                                      'is_closed','url','rating',
                                      'transactions','location.address2',
                                      'location.address3'], axis=1)

# %%
df_nested_list
# Out:
#                         name  review_count         phone      distance  \
# 0  Zeds Real Fruit Ice Cream            13  +15033955038   5614.057431
# 1          Ani’s Day & Night            10  +15127751355  11097.854408
# 2                       1417             3                 6116.809131
# 3            Eat My Biscuits            20  +15125911129  36157.748173
# 4          Dutch Bros Coffee             8  +15419554700  25651.504768
#
#    coordinates.latitude  coordinates.longitude        location.address1  \
# 0             30.282100             -97.705730           1814 Harvey St
# 1             30.221010             -97.695600      7107 E Riverside Dr
# 2             30.250214             -97.754573            1417 S 1st St
# 3             30.630148             -97.745067      3309 W State Hwy 29
# 4             30.519441             -97.658651  1700 E Palm Valley Blvd
#
#   location.city location.zip_code location.country location.state  \
# 0        Austin             78702               US             TX
# 1        Austin             78741               US             TX
# 2        Austin             78704               US             TX
# 3    Georgetown             78628               US             TX
# 4    Round Rock             78664               US             TX
#
#                           location.display_address
# 0               [1814 Harvey St, Austin, TX 78702]
# 1          [7107 E Riverside Dr, Austin, TX 78741]
# 2                [1417 S 1st St, Austin, TX 78704]
# 3      [3309 W State Hwy 29, Georgetown, TX 78628]
# 4  [1700 E Palm Valley Blvd, Round Rock, TX 78664]

# %% [markdown]
# # Housing Market Analysis by zipcode
#
# source: https://data.austintexas.gov/Housing-and-Real-Estate/2014-Housing-Market-Analysis-Data-by-Zip-Code/hcnj-rei3

# %%
df = pd.read_csv('../2014_Housing_Market_Analysis_Data_by_Zip_Code.csv')
df.dropna()
df.head()
# Out:
#    Zip Code  Population below poverty level  Median household income  \
# 0   78726.0                               9                    66096
# 1       NaN                              19                    52431
# 2   78724.0                              38                    35711
# 3   78617.0                              18                    43957
# 4   78701.0                              20                    68152
#
#    Non-White, Non-Hispanic or Latino  Hispanic or Latino, of any race  \
# 0                                 16                               20
# 1                                 16                               35
# 2                                 29                               63
# 3                                 12                               67
# 4                                 16                               14
#
#    Population with disability  Unemployment  Large households (5+ members)  \
# 0                           3             4                              2
# 1                           8             7                              8
# 2                           8             8                             28
# 3                          10            15                             23
# 4                          10             9                              0
#
#    Homes affordable to people earning less than $50,000  \
# 0                                                0.0
# 1                                               24.0
# 2                                               85.0
# 3                                                NaN
# 4                                                7.0
#
#    Rentals affordable to people earning less than $25,000  ...  \
# 0                                                  1       ...
# 1                                                 10       ...
# 2                                                 16       ...
# 3                                                 11       ...
# 4                                                  7       ...
#
#    Rental units affordable to average teacher  \
# 0                                          70
# 1                                          74
# 2                                          78
# 3                                          63
# 4                                          29
#
#    Owner units affordable to average teacher  \
# 0                                        0.0
# 1                                       22.0
# 2                                       84.0
# 3                                        NaN
# 4                                        7.0
#
#    Rental units affordable to average tech worker  \
# 0                                              99
# 1                                              98
# 2                                             100
# 3                                              99
# 4                                              90
#
#    Owner units affordable to average tech worker  \
# 0                                           17.0
# 1                                           58.0
# 2                                           96.0
# 3                                            NaN
# 4                                           30.0
#
#    Change in percentage of population below poverty, 2000-2012  \
# 0                                                375
# 1                                                 65
# 2                                                208
# 3                                                101
# 4                                                 12
#
#    Change in median rent, 2000-2012  Change in median home value, 2000-2012  \
# 0                                20                                      55
# 1                                31                                      74
# 2                                37                                      46
# 3                                74                                      21
# 4                               115                                      59
#
#    Percentage of homes within 1/4-mi of transit stop  \
# 0                                                  2
# 1                                                 29
# 2                                                 21
# 3                                                 16
# 4                                                 97
#
#    Average monthly transportation cost  \
# 0                                  786
# 1                                  668
# 2                                  786
# 3                                  865
# 4                                  433
#
#    Percentage of housing and transportation costs that is transportation-related
# 0                                                 40
# 1                                                 38
# 2                                                 40
# 3                                                 42
# 4                                                 23
#
# [5 rows x 30 columns]

# %%
# df = df.drop(columns=['Population below poverty level',
#                       'Non-White, Non-Hispanic or Latino',
#                       'Hispanic or Latino, of any race',
#                       'Population with disability',
#                       'Unemployment',
#                       'Large households (5+ members)',
#                       'Rentals affordable to people earning less than $25,000',
#                       'Rent-restricted units',
#                       'Housing Choice Voucher holders',
#                       'Percentage of rental units in poor condition',
#                       'Rental units affordable to average teacher',
#                       'Owner units affordable to average teacher',
#                       'Rental units affordable to average tech worker',
#                       'Owner units affordable to average tech worker',
#                       'Change in percentage of population below poverty, 2000-2012',
#                       'Percentage of homes within 1/4-mi of transit stop',
#                       'Percentage of housing and transportation costs that is transportation-related',
#                       'Average monthly transportation cost',
#                       'Owner units affordable to average artist',
#                       'Homes affordable to people earning less than $50,000',
#                       'Median rent','Percent change in number of housing units, 2000-2012',
#                       'Change in median rent, 2000-2012',
#                       'Rental units affordable to average artist',
#                       'Rental units affordable to average retail/service worker',
#                       'Owner units affordable to average retail/service worker',
#                       'Change in median home value, 2000-2012'])
df = df[['Zip Code','Median household income','Median home value','Change in median rent, 2000-2012']]
df.head()
# Out:
#    Zip Code  Median household income  Median home value  \
# 0   78726.0                    66096             349900
# 1       NaN                    52431             216700
# 2   78724.0                    35711             105700
# 3   78617.0                    43957             100600
# 4   78701.0                    68152             338300
#
#    Change in median rent, 2000-2012
# 0                                20
# 1                                31
# 2                                37
# 3                                74
# 4                               115

# %% [markdown]
# # ATX housing data
#
# limitations:
# - most recent version from earlier this year so some of these properties are no longer available and the prices are not accurate

# %%
df = pd.read_csv('../austinHousingData.csv')
df
# Out:
#              zpid          city                   streetAddress  zipcode  \
# 0       111373431  pflugerville            14424 Lake Victor Dr    78660
# 1       120900430  pflugerville              1104 Strickling Dr    78660
# 2      2084491383  pflugerville             1408 Fort Dessau Rd    78660
# 3       120901374  pflugerville              1025 Strickling Dr    78660
# 4        60134862  pflugerville           15005 Donna Jane Loop    78660
# ...           ...           ...                             ...      ...
# 15166    29512934        austin                 905 Silcantu Dr    78748
# 15167   241937773        austin  1413 Waterloo Shore Ln UNIT 12    78741
# 15168    29473281        austin                   2206 S 3rd St    78704
# 15169    29392029        austin               2000 Chestnut Ave    78722
# 15170    29390174        austin                  3110 E 12th St    78702
#
#                                              description   latitude  \
# 0      14424 Lake Victor Dr, Pflugerville, TX 78660 i...  30.430632
# 1      Absolutely GORGEOUS 4 Bedroom home with 2 full...  30.432673
# 2      Under construction - estimated completion in A...  30.409748
# 3      Absolutely darling one story home in charming ...  30.432112
# 4      Brimming with appeal & warm livability! Sleek ...  30.437368
# ...                                                  ...        ...
# 15166  Not for rent!\r\n\r\nBeautiful one story home ...  30.161997
# 15167  This contemporary three-story detached condo h...  30.240223
# 15168  Original bungalow with a modern addition. Larg...  30.244835
# 15169  So many options at this address in the eclecti...  30.281569
# 15170  3110 E 12th St, Austin, TX 78702 is a single f...  30.276930
#
#        longitude  propertyTaxRate  garageSpaces  hasAssociation  ...  \
# 0     -97.663078             1.98             2            True  ...
# 1     -97.661697             1.98             2            True  ...
# 2     -97.639771             1.98             0            True  ...
# 3     -97.661659             1.98             2            True  ...
# 4     -97.656860             1.98             0            True  ...
# ...          ...              ...           ...             ...  ...
# 15166 -97.816345             1.98             6           False  ...
# 15167 -97.772835             1.98             2            True  ...
# 15168 -97.761124             1.98             2           False  ...
# 15169 -97.717789             1.98             0           False  ...
# 15170 -97.701523             1.98             1           False  ...
#
#        numOfMiddleSchools  numOfHighSchools  avgSchoolDistance  \
# 0                       1                 1           1.266667
# 1                       1                 1           1.400000
# 2                       1                 1           1.200000
# 3                       1                 1           1.400000
# 4                       1                 1           1.133333
# ...                   ...               ...                ...
# 15166                   1                 1           0.900000
# 15167                   1                 1           1.900000
# 15168                   1                 1           0.800000
# 15169                   1                 1           1.300000
# 15170                   1                 1           1.900000
#
#        avgSchoolRating  avgSchoolSize MedianStudentsPerTeacher  \
# 0             2.666667           1063                       14
# 1             2.666667           1063                       14
# 2             3.000000           1108                       14
# 3             2.666667           1063                       14
# 4             4.000000           1223                       14
# ...                ...            ...                      ...
# 15166         3.333333           1424                       14
# 15167         6.666667           1226                       16
# 15168         5.000000            889                       13
# 15169         6.666667           1057                       15
# 15170         6.666667           1057                       15
#
#        numOfBathrooms  numOfBedrooms  numOfStories  \
# 0                 3.0              4             2
# 1                 2.0              4             1
# 2                 2.0              3             1
# 3                 2.0              3             1
# 4                 3.0              3             2
# ...               ...            ...           ...
# 15166             2.0              3             1
# 15167             4.0              3             3
# 15168             3.0              3             2
# 15169             2.0              4             1
# 15170             1.0              2             1
#
#                                                homeImage
# 0      111373431_ffce26843283d3365c11d81b8e6bdc6f-p_f...
# 1      120900430_8255c127be8dcf0a1a18b7563d987088-p_f...
# 2      2084491383_a2ad649e1a7a098111dcea084a11c855-p_...
# 3      120901374_b469367a619da85b1f5ceb69b675d88e-p_f...
# 4      60134862_b1a48a3df3f111e005bb913873e98ce2-p_f.jpg
# ...                                                  ...
# 15166  29512934_ff9b6eefa7e2eb4e9ef983da13a23098-p_f.jpg
# 15167  241937773_66d3e483bd783eac5a52ff5f938d2a2e-p_f...
# 15168  29473281_9e90ec4652c4b3b6592a7fdd09f1ea6d-p_f.jpg
# 15169  29392029_a9a8306ea363d23f37d91d37975a1b96-p_f.jpg
# 15170  29390174_9580c60e14870498b2ce98b5f889471e-p_f.jpg
#
# [15171 rows x 47 columns]

# %%
df.zipcode.value_counts()
# Out:
# 78748    1144
# 78745    1039
# 78749     774
# 78704     706
# 78737     617
# 78739     605
# 78732     597
# 78759     561
# 78723     558
# 78757     523
# 78717     516
# 78731     495
# 78744     472
# 78753     442
# 78727     417
# 78702     397
# 78758     395
# 78754     393
# 78747     381
# 78750     321
# 78729     318
# 78735     311
# 78703     302
# 78721     255
# 78730     244
# 78728     225
# 78741     224
# 78724     223
# 78733     214
# 78746     195
# 78726     178
# 78751     174
# 78736     163
# 78725     162
# 78752     153
# 78756     140
# 78722     100
# 78617      86
# 78705      68
# 78660      36
# 78619      12
# 78734       9
# 78701       8
# 78719       5
# 78653       4
# 78652       4
# 78742       4
# 78738       1
# Name: zipcode, dtype: int64
